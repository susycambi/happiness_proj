# %%
import pandas as pd

# %%
wh_all_df = pd.read_excel("WHR21.xls")

# %%
wh_all_df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
cols_of_interest = wh_all_df.columns[1:9]

# %%
cols_of_interest
# Out:
# Index(['year', 'Life Ladder', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption'],
#       dtype='object')

# %%
wh_withna_df = wh_all_df[cols_of_interest]

# %%
wh_withna_df
# Out:
#       year  Life Ladder  Log GDP per capita  Social support  \
# 0     2008     3.723590            7.370100        0.450662
# 1     2009     4.401778            7.539972        0.552308
# 2     2010     4.758381            7.646709        0.539075
# 3     2011     3.831719            7.619532        0.521104
# 4     2012     3.782938            7.705479        0.520637
# ...    ...          ...                 ...             ...
# 1944  2016     3.735400            7.984372        0.768425
# 1945  2017     3.638300            8.015738        0.754147
# 1946  2018     3.616480            8.048798        0.775388
# 1947  2019     2.693523            7.950132        0.759162
# 1948  2020     3.159802            7.828757        0.717243
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# 2                            51.599998                      0.600127
# 3                            51.919998                      0.495901
# 4                            52.240002                      0.530935
# ...                                ...                           ...
# 1944                         54.400002                      0.732971
# 1945                         55.000000                      0.752826
# 1946                         55.599998                      0.762675
# 1947                         56.200001                      0.631908
# 1948                         56.799999                      0.643303
#
#       Generosity  Perceptions of corruption
# 0       0.167640                   0.881686
# 1       0.190099                   0.850035
# 2       0.120590                   0.706766
# 3       0.162427                   0.731109
# 4       0.236032                   0.775620
# ...          ...                        ...
# 1944   -0.094634                   0.723612
# 1945   -0.097645                   0.751208
# 1946   -0.068427                   0.844209
# 1947   -0.063791                   0.830652
# 1948   -0.008696                   0.788523
#
# [1949 rows x 8 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(wh_withna_df)

# %%
wh_withna_df.isna().sum()
# Out:
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   36
# Social support                       13
# Healthy life expectancy at birth     55
# Freedom to make life choices         32
# Generosity                           89
# Perceptions of corruption           110
# dtype: int64

# %%
wh_withna_df.shape
# Out:
# (1949, 8)

# %%
wh_df = wh_withna_df.dropna()

# %%
wh_df.isna().sum()
# Out:
# year                                0
# Life Ladder                         0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# dtype: int64

# %%
wh_df.shape
# Out:
# (1712, 8)

# %%
wh_df.corr()
# Out:
#                                       year  Life Ladder  Log GDP per capita  \
# year                              1.000000     0.065547            0.093309
# Life Ladder                       0.065547     1.000000            0.793117
# Log GDP per capita                0.093309     0.793117            1.000000
# Social support                    0.010695     0.713205            0.706366
# Healthy life expectancy at birth  0.184058     0.754781            0.860167
# Freedom to make life choices      0.252669     0.523966            0.351970
# Generosity                       -0.035485     0.182106           -0.025051
# Perceptions of corruption        -0.099451    -0.448568           -0.343976
#
#                                   Social support  \
# year                                    0.010695
# Life Ladder                             0.713205
# Log GDP per capita                      0.706366
# Social support                          1.000000
# Healthy life expectancy at birth        0.616980
# Freedom to make life choices            0.410381
# Generosity                              0.055537
# Perceptions of corruption              -0.227290
#
#                                   Healthy life expectancy at birth  \
# year                                                      0.184058
# Life Ladder                                               0.754781
# Log GDP per capita                                        0.860167
# Social support                                            0.616980
# Healthy life expectancy at birth                          1.000000
# Freedom to make life choices                              0.384187
# Generosity                                                0.017929
# Perceptions of corruption                                -0.335347
#
#                                   Freedom to make life choices  Generosity  \
# year                                                  0.252669   -0.035485
# Life Ladder                                           0.523966    0.182106
# Log GDP per capita                                    0.351970   -0.025051
# Social support                                        0.410381    0.055537
# Healthy life expectancy at birth                      0.384187    0.017929
# Freedom to make life choices                          1.000000    0.326934
# Generosity                                            0.326934    1.000000
# Perceptions of corruption                            -0.487262   -0.287685
#
#                                   Perceptions of corruption
# year                                              -0.099451
# Life Ladder                                       -0.448568
# Log GDP per capita                                -0.343976
# Social support                                    -0.227290
# Healthy life expectancy at birth                  -0.335347
# Freedom to make life choices                      -0.487262
# Generosity                                        -0.287685
# Perceptions of corruption                          1.000000

# %%
sns.heatmap(wh_df.corr())
# Out:
# <AxesSubplot:>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from happypred import whdata_to_csv

# %%
whdata_to_csv("WHR21.xls")
# Out:
# ('X_train.csv', 'y_train.csv', 'X_test.csv', 'y_test.csv')

# %%
 y_tra
